# %% [markdown]
# <a href="https://colab.research.google.com/github/chimaya442004/data-science-practical/blob/main/pratical_7_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/Hotel ReservatioOON.xlsx")
data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("/content/Cost_of_puppy.jpg")
plt.imshow(img)

# %%
import pandas as pd
df=pd.DataFrame({"serial_no":[1,2,3,4,5],"roll_no":[11,22,33,44,55],"name":["chimu","mansi","ankita","neha","partiksha"]})
df
# Out:
#    serial_no  roll_no       name
# 0          1       11      chimu
# 1          2       22      mansi
# 2          3       33     ankita
# 3          4       44       neha
# 4          5       55  partiksha

# %%
df.isnull()
# Out:
#    serial_no  roll_no   name
# 0      False    False  False
# 1      False    False  False
# 2      False    False  False
# 3      False    False  False
# 4      False    False  False

# %% [markdown]
# sumaraies the data

# %%
import pandas as pd
data=pd.DataFrame({'Roll no':[6195,6196,6197,6198,6199,6196],
                   'Name':['ankita','chimaya','mansi','pratiksha','neha','chimaya'],
                   'Marks':[85,89,76,79,80,89],
                   'Class':['A','B','A','B','A','B']})
data
# Out:
#    Roll no       Name  Marks Class
# 0     6195     ankita     85     A
# 1     6196    chimaya     89     B
# 2     6197      mansi     76     A
# 3     6198  pratiksha     79     B
# 4     6199       neha     80     A
# 5     6196    chimaya     89     B

# %%
data.isnull()
# Out:
#    Roll no   Name  Marks  Class
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False
# 5    False  False  False  False

# %%
data.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# Class      0
# dtype: int64

# %%
data.describe()
# Out:
#            Roll no      Marks
# count     6.000000   6.000000
# mean   6196.833333  83.000000
# std       1.471960   5.477226
# min    6195.000000  76.000000
# 25%    6196.000000  79.250000
# 50%    6196.500000  82.500000
# 75%    6197.750000  88.000000
# max    6199.000000  89.000000

# %%
data.describe(include='object')
# Out:
#            Name Class
# count         6     6
# unique        5     2
# top     chimaya     A
# freq          2     3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  6 non-null      int64
#  1   Name     6 non-null      object
#  2   Marks    6 non-null      int64
#  3   Class    6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
data.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# Class      2
# dtype: int64

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data['Name']
# Out:
# 0       ankita
# 1      chimaya
# 2        mansi
# 3    pratiksha
# 4         neha
# 5      chimaya
# Name: Name, dtype: object

# %%
data['Name'].duplicated().sum()
# Out:
# 1

# %%
data['Name'].value_counts()
# Out:
# chimaya      2
# ankita       1
# mansi        1
# pratiksha    1
# neha         1
# Name: Name, dtype: int64

# %%
data.value_counts()
# Out:
# Roll no  Name       Marks  Class
# 6196     chimaya    89     B        2
# 6195     ankita     85     A        1
# 6197     mansi      76     A        1
# 6198     pratiksha  79     B        1
# 6199     neha       80     A        1
# dtype: int64

# %%
data.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# Class      2
# dtype: int64

# %%
data['Marks'].mean()
# Out:
# 83.0

# %%
data['Marks'].var()
# Out:
# 30.0

# %%
 correlation=data.corr()
 print(correlation)
# Out:
#           Roll no     Marks
# Roll no  1.000000 -0.644981
# Marks   -0.644981  1.000000
# <ipython-input-71-ac989fe7b573>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=data.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(correlation,annot=True,fmt='2f')
# Out:
# <Axes: >

# %%
sns.heatmap(correlation,annot=True,fmt='2f',cmap='plasma')
# Out:
# <Axes: >
